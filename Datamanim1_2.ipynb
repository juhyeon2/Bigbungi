# %% [markdown]
# <a href="https://colab.research.google.com/github/juhyeon2/Bigbungi/blob/main/Datamanim1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 03 Grouping

# %%
# Q-44 데이터 로딩
url = 'https://raw.githubusercontent.com/Datamanim/pandas/main/AB_NYC_2019.csv'
df = pd.read_csv(url)
df.head(5)

# %%
# Q-45
# ans = df.groupby('host_name').size()
ans = df.host_name.value_counts().sort_index()
ans.head(5)

# %%
# Q-46 ###
# ans = df.host_name.value_counts().sort_values(ascending=False)
ans = df.groupby('host_name').size().to_frame().rename(columns={0:'counts'})
ans = ans.sort_values('counts',ascending=False)
ans.head(5)

# %%
# Q-47 ###
ans = df.groupby(['neighbourhood_group','neighbourhood'], as_index=False).size()
ans.head(4)

# %%
# Q-48 ###
ans = df.groupby(['neighbourhood_group','neighbourhood'], as_index=False).size()
ans = ans.groupby(['neighbourhood_group'], as_index=False).max()
ans

# %%
# Q-49
# df.groupby('neighbourhood_group')['price'].agg(['mean','var','max','min'])
df[['neighbourhood_group','price']].groupby('neighbourhood_group').agg(['mean','var','max','min'])

# %%
# Q-50
# df.groupby('neighbourhood_group')['reviews_per_month'].agg(['mean','var','max','min'])
ans = df[['neighbourhood_group','reviews_per_month']].groupby('neighbourhood_group')
ans = ans.agg(['mean','var','max','min'])
ans

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
